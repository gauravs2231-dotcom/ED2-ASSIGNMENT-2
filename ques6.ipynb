# %%
import numpy as np
import matplotlib.pyplot as plt

# constants (CGS)
k= 1.3807e-16 # erg/K
m= 9.109e-28# g
C= 6.8e-38 # erg s^-1 cm^3 Hz^-1
B= 1.66166*2
h= 6.626e-27  
gff = 1.2       
z = 1          
ne = 1   # per unit cm^3
ni = 1          
v = np.logspace(8, 20, 600)  # frequency range (Hz)

def power(v, t):
   x = h * v/ (k * t)
   return C * Z**2 * ne * ni * gff * (2*k*T/m)**(-0.5) * np.exp(-x) * (2.2 + 2.2*x + 0.6*x**2) / B

plt.figure()
plt.loglog(v, power(v, 300), 'g', label='T=300 K')
plt.loglog(v, power(v, 1e6), 'b', label='T=1e6 K')
plt.xlabel('Frequency (Hz)')
plt.ylabel(' Emiited Power per Volume per Frequency(CGS units)')
plt.title('Thermal Bremsstrahlung Emission (gff = 1.2)')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
